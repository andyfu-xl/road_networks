# %%
from utils import get_trajectories, plot_trajectories, to_csv, randomTrips
# Out:
# SUMO_HOME found

# %%
randomTrips(dur=10000, density=3)
trajectories = get_trajectories()
# Out:
# Success.
#  Retrying in 1 seconds
# ***Starting server on port 49815 ***
# Loading net-file from './config/osm.net.xml.gz' ... done (106ms).
# Loading done.
# Simulation version 1.20.0 started with time: 0.00.
# Simulation ended at time: 10777.00
# Reason: TraCI requested termination.
# Performance:
#  Duration: 61.32s
#  TraCI-Duration: 56.61s
#  Real time factor: 175.75
#  UPS: 19100.750163
# Vehicles:
#  Inserted: 2199
#  Running: 0
#  Waiting: 0
# Statistics (avg of 2199):
#  RouteLength: 4984.74
#  Speed: 9.48
#  Duration: 532.63
#  WaitingTime: 19.92
#  TimeLoss: 76.98
#  DepartDelay: 0.53

# %%
plot_trajectories(trajectories, 1000)

# %%
to_csv(trajectories)
