# %%
import torch
import torch.optim as optim
from torch.utils.data import DataLoader
from sumolib import checkBinary
import torch.nn.functional as F
from utils import *
from Models import GRUModel
from Datasets import DatasetWithPlans
from CustomMSE import CustomMSE

# use gpu if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device: " + str(device))
# Out:
# SUMO_HOME found
# Using device: cuda

# %%
planned_path = get_planned_path()
checkpoints = list(planned_path.values())
checkpoints = torch.tensor(checkpoints).float() / 10
# Out:
#  Retrying in 1 seconds
# ***Starting server on port 41571 ***
# Loading net-file from './config/osm.net.xml.gz' ... done (109ms).
# Loading done.
# Simulation version 1.20.0 started with time: 0.00.
# Simulation ended at time: 10777.00
# Reason: TraCI requested termination.
# Performance:
#  Duration: 8.43s
#  TraCI-Duration: 4.86s
#  Real time factor: 1277.96
#  UPS: 138889.837543
# Vehicles:
#  Inserted: 2199
#  Running: 0
#  Waiting: 0
# Statistics (avg of 2199):
#  RouteLength: 4984.74
#  Speed: 9.48
#  Duration: 532.63
#  WaitingTime: 19.92
#  TimeLoss: 76.98
#  DepartDelay: 0.53

# %%
df = pd.read_csv('edinburgh_trajectories.csv')
num_cols = df.shape[1]
position_indices = [i for i in range(num_cols) if i % 4 == 1 or i % 4 == 2]
position_df = df.iloc[:, position_indices]
position_array = position_df.to_numpy()
sequence_length = len(position_indices) // 2
tensor_list = []

for row in position_array:
    reshaped_tensor = torch.tensor(row.reshape(sequence_length, 2))
    tensor_list.append(reshaped_tensor)

all_trajectories_tensor = torch.stack(tensor_list).float() / 10

next_checkpoint = torch.zeros_like(all_trajectories_tensor)
next_next_checkpoint = torch.zeros_like(all_trajectories_tensor)
checkpoints_pad_1 = F.pad(checkpoints, (0, 0, 1, 0))
for i in range(all_trajectories_tensor.shape[1]):
    _, min_indices = project_to_nearest(all_trajectories_tensor[:, i], checkpoints)
    next_checkpoint[:, i] = checkpoints_pad_1[range(checkpoints.shape[0]), min_indices+1]
    next_next_checkpoint[:, i] = checkpoints_pad_1[range(checkpoints.shape[0]), min_indices+2]

all_trajectories_tensor = torch.cat((all_trajectories_tensor, next_checkpoint, next_next_checkpoint), dim=2)

# %%
# break trajectories into 1000 by 1000 cells
trajectory_list = []
checkpoints_list = []
for i in range(all_trajectories_tensor.shape[0]):
    trajectory = all_trajectories_tensor[i]
    path = checkpoints[i]
    modif = (trajectory[0, :2] - torch.tensor([50, 50])).repeat(1, 3)
    to_add = []
    for j in range(trajectory.shape[0]):
        trajectory_j = (trajectory[j] - modif).squeeze()
        # break if end of trajectory =============================
        if trajectory[j, :2].max() == 0: 
            if trajectory[j:, :2].max() == 0:
                break
        # ========================================================
        # if vehicle moves out of the previous box, add the trajectory and checkpoints.
        if trajectory_j[0] < 0 or trajectory_j[0] > 100 or trajectory_j[1] < 0 or trajectory_j[1] > 100 or (j == trajectory.shape[0] - 1):
            # add the trajectory to list
            trajectory_list.append(torch.stack(to_add))
            checkpoints_list.append(path-modif.squeeze()[:2])

            # reset the to_add list, adding a part of the history to the new trajectory
            if j != trajectory.shape[0] - 1:
                modif = (trajectory[j, :2] - torch.tensor([50, 50])).repeat(1, 3)
                rewind = 0
                while True:
                    trajectory_k = (trajectory[j - rewind] - modif).squeeze()
                    if trajectory_k[0] < 0 or trajectory_k[0] > 100 or trajectory_k[1] < 0 or trajectory_k[1] > 100:
                        rewind += 1
                    else:
                        break
                to_add = to_add[:-rewind]
        else:
            to_add.append(trajectory_j)

# %%
checkpoints = torch.stack(checkpoints_list)
def pad_tensors(tensors):
    max_length = max([t.shape[0] for t in tensors])
    padded_tensors = []
    for tensor in tensors:
        padded_tensor = F.pad(tensor, (0, 0, 0, max_length - tensor.shape[0]))
        padded_tensors.append(padded_tensor)
    return torch.stack(padded_tensors)

all_trajectories_tensor = pad_tensors(trajectory_list)

# %%
# split the data into training and validation sets
# because the data is randomly generated, we don't need to shuffle it
train_ratio = 0.8
train_size = int(train_ratio * all_trajectories_tensor.shape[0])
train_trajectories_tensor = all_trajectories_tensor[:train_size]
val_trajectories_tensor = all_trajectories_tensor[train_size:]

train_checkpoints = checkpoints[:train_size]
val_checkpoints = checkpoints[train_size:]

train_mask = generate_masks(train_trajectories_tensor)
    
train_dataset = DatasetWithPlans(train_trajectories_tensor, train_mask, train_checkpoints)

# %%
def train_model(model, dataloader, epochs, optimizer, criterion):
    model.train()
    for epoch in range(epochs):
        total_loss = 0
        for inputs, masks, planned_path in dataloader:
            optimizer.zero_grad()
            hidden = None
            loss = 0
            steps = 0
            # Autoregressive prediction
            # Start with the first input and predict each subsequent step
            seq_len = inputs.size(1)
            current_input = inputs[:, 0, :].unsqueeze(1)
            modifications = (current_input[:, :, :2] - torch.ones_like(current_input[:, :, :2]) * 500).repeat(1, 1, 3)
            current_input -= modifications
            for t in range(1, seq_len):
                new_steps = int(sum((inputs[:, t, :2].reshape(-1) != 0).float().to(device))) / 2
                if new_steps == 0:
                    break
                prediction, hidden = model(current_input, hidden)
                steps += new_steps

                previous_input = inputs[:, t-1, :2]
                if epoch > 10:
                    projection_with_checkpoints = project_to_nearest_with_checkpoints(prediction, planned_path)
                    current_input = (projection_with_checkpoints * masks[:, t, :] + inputs[:, t, :] * (1-masks[:, t, :])).unsqueeze(1)
                else:
                    current_input = inputs[:, t, :].unsqueeze(1)
                if t > 1:
                    loss += criterion(prediction - previous_input, inputs[:, t, :2]-previous_input) #(current_input-previous_input).squeeze(1))
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
 
        print(f'Epoch {epoch+1}, Loss: {total_loss / len(dataloader)}')

train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)

model = GRUModel(input_size=6, hidden_size=256, num_layers=2, num_classes=2).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = CustomMSE()
train_model(model, train_dataloader, 20, optimizer, criterion)
# Out:
# Epoch 1, Loss: 75657.42232730263
# Epoch 2, Loss: 4959.293585526316
# Epoch 3, Loss: 3394.9850123355263
# Epoch 4, Loss: 3264.0158074629935
# Epoch 5, Loss: 3173.774845805921
# Epoch 6, Loss: 3023.5175151624176
# Epoch 7, Loss: 3060.0874640213815
# Epoch 8, Loss: 2832.5075940583883
# Epoch 9, Loss: 2868.9388100071956
# Epoch 10, Loss: 2922.751793148643
# Epoch 11, Loss: 2898.9322464792353
# Epoch 12, Loss: 3121.9904393246297
# Epoch 13, Loss: 3046.483006527549
# Epoch 14, Loss: 2981.6777472245067
# Epoch 15, Loss: 3012.9392192639802
# Epoch 16, Loss: 3020.493773129112
# Epoch 17, Loss: 3100.5784089740955
# Epoch 18, Loss: 3105.2942434210527
# Epoch 19, Loss: 2977.153113435444
# Epoch 20, Loss: 2971.928351793791

# %%
def checkModel(model, inputs, masks, paths):
    model.eval()
    with torch.no_grad():
        hidden = None
        seq_len = inputs.size(1)
        current_input = inputs[:, 0, :].unsqueeze(1)
        for t in range(1, seq_len):
            prediction, hidden = model(current_input, hidden)
            projection_with_checkpoints = project_to_nearest_with_checkpoints(prediction, paths)
            current_input = (projection_with_checkpoints * masks[:, t, :] + inputs[:, t, :] * (1-masks[:, t, :])).unsqueeze(1)
            print(projection_with_checkpoints[0][:2]*10, inputs[:, t, :][0][:2]*10)

# get the first batch in dataloader
val_mask = generate_masks(val_trajectories_tensor, missing_ratio=0.9, complete_traj_ratio=0)
val_dataset = DatasetWithPlans(val_trajectories_tensor, val_mask, val_checkpoints)
val_dataloader = DataLoader(val_dataset, batch_size=64, shuffle=True)
inputs, masks, paths = next(iter(val_dataloader))

checkModel(model, inputs, masks, paths)
# Out:
# tensor([328.9350, 263.5667], device='cuda:0') tensor([512.5598, 510.2237], device='cuda:0')
# tensor([523.6014, 519.2115], device='cuda:0') tensor([519.0472, 515.5042], device='cuda:0')
# tensor([524.5873, 520.0140], device='cuda:0') tensor([525.2734, 520.5725], device='cuda:0')
# tensor([515.0579, 512.2570], device='cuda:0') tensor([531.9470, 526.0593], device='cuda:0')
# tensor([507.8930, 506.4247], device='cuda:0') tensor([538.7842, 531.6913], device='cuda:0')
# tensor([505.9142, 504.8140], device='cuda:0') tensor([545.6262, 537.3279], device='cuda:0')
# tensor([505.5941, 504.5534], device='cuda:0') tensor([551.7230, 542.3502], device='cuda:0')
# tensor([559.7457, 549.4872], device='cuda:0') tensor([558.0524, 547.9959], device='cuda:0')
# tensor([571.8138, 559.6635], device='cuda:0') tensor([563.9771, 553.1046], device='cuda:0')
# tensor([575.7335, 562.9268], device='cuda:0') tensor([570.7880, 558.8092], device='cuda:0')
# tensor([578.6237, 565.2683], device='cuda:0') tensor([577.3798, 564.2642], device='cuda:0')
# tensor([584.2201, 569.7860], device='cuda:0') tensor([583.9508, 569.5685], device='cuda:0')
# tensor([588.6158, 573.3117], device='cuda:0') tensor([590.2625, 574.6158], device='cuda:0')
# tensor([595.0370, 578.3979], device='cuda:0') tensor([596.9904, 579.9417], device='cuda:0')
# tensor([600.2903, 582.5338], device='cuda:0') tensor([603.5925, 585.1273], device='cuda:0')
# tensor([607.4158, 588.1110], device='cuda:0') tensor([610.0580, 590.1508], device='cuda:0')
# tensor([615.7305, 594.5308], device='cuda:0') tensor([617.0062, 595.4861], device='cuda:0')
# tensor([624.2676, 601.6589], device='cuda:0') tensor([620.3394, 597.9794], device='cuda:0')
# tensor([632.8181, 619.1329], device='cuda:0') tensor([621.0303, 598.4964], device='cuda:0')
# tensor([626.5577, 632.3762], device='cuda:0') tensor([621.5186, 598.8617], device='cuda:0')
# tensor([628.5543, 606.5945], device='cuda:0') tensor([621.5771, 598.9056], device='cuda:0')
# tensor([632.2004, 624.3049], device='cuda:0') tensor([621.6138, 598.9334], device='cuda:0')
# tensor([624.9451, 634.6829], device='cuda:0') tensor([621.6144, 598.9334], device='cuda:0')
# tensor([628.0950, 606.0656], device='cuda:0') tensor([621.6144, 598.9334], device='cuda:0')
# tensor([627.9186, 605.8626], device='cuda:0') tensor([621.6144, 598.9334], device='cuda:0')
# tensor([629.3879, 607.5543], device='cuda:0') tensor([621.6144, 598.9334], device='cuda:0')
# tensor([631.5558, 625.2269], device='cuda:0') tensor([621.6144, 598.9334], device='cuda:0')
# tensor([623.6570, 635.5726], device='cuda:0') tensor([621.6144, 598.9334], device='cuda:0')
# tensor([610.6492, 644.5579], device='cuda:0') tensor([621.6144, 598.9334], device='cuda:0')
# tensor([598.1177, 651.2133], device='cuda:0') tensor([621.6144, 598.9334], device='cuda:0')
# tensor([578.9037, 661.3718], device='cuda:0') tensor([621.6144, 598.9334], device='cuda:0')
# tensor([557.1047, 679.4270], device='cuda:0') tensor([621.6144, 598.9334], device='cuda:0')
# tensor([544.0319, 703.7360], device='cuda:0') tensor([621.6144, 598.9334], device='cuda:0')
# tensor([532.4431, 728.5609], device='cuda:0') tensor([621.6144, 598.9334], device='cuda:0')
# tensor([522.9771, 749.2717], device='cuda:0') tensor([621.6144, 598.9334], device='cuda:0')
# tensor([514.3256, 768.9139], device='cuda:0') tensor([621.6144, 598.9334], device='cuda:0')
# tensor([504.8732, 791.2799], device='cuda:0') tensor([621.6144, 598.9334], device='cuda:0')
# tensor([493.6143, 817.9199], device='cuda:0') tensor([623.4314, 600.6961], device='cuda:0')
# tensor([482.0793, 844.9387], device='cuda:0') tensor([626.6785, 604.4342], device='cuda:0')
# tensor([468.9806, 873.9434], device='cuda:0') tensor([631.3086, 609.7659], device='cuda:0')
device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([519.9548,   3.5428], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([379.8858, 202.4489], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([438.8933, 129.4332], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([462.2046, 102.8726], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([462.2046, 102.8726], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([326.0553, 267.0823], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([445.2380, 121.5820], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([326.0553, 267.0823], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([426.0509, 145.3250], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([520.1845,  72.8585], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([519.9519,  44.8456], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([519.6252,   6.0028], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([397.8206, 180.3515], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([450.9666, 114.4933], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([462.2046, 102.8726], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.3077, 102.5576], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([326.0553, 267.0823], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([440.8170, 127.0528], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([520.1260,  65.8104], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([519.8475,  32.7697], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([519.6451,   7.6289], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([435.6562, 133.4389], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([460.3247, 104.3228], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([474.8151,  99.7629], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([326.0553, 267.0823], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([446.4584, 120.0719], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([520.0652,  58.4841], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([519.7861,  25.1421], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([519.9548,   3.5428], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([395.4235, 183.3398], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([445.9087, 120.7522], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([462.2046, 102.8726], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([326.0553, 267.0823], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([444.1193, 122.9664], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([520.0816,  60.4642], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([519.7987,  26.7089], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([519.9548,   3.5428], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([395.8453, 182.8140], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([446.0457, 120.5827], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([331.8146, 260.0512], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([449.6512, 116.1210], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([520.0654,  58.5220], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([519.7850,  25.0104], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([519.9548,   3.5428], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([393.9368, 185.1932], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([446.7396, 119.7240], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([462.2046, 102.8726], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([462.2046, 102.8726], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([326.0553, 267.0823], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([437.0159, 131.7564], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([520.1835,  72.7316], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([519.9183,  41.1740], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([519.7258,  17.6549], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([520.4241,   2.7275], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([392.2503, 187.2956], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([441.2885, 126.4694], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([461.7706, 103.2074], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([462.2046, 102.8726], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([326.0553, 267.0823], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([440.1408, 127.8895], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([520.1396,  67.4559], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([519.8655,  35.0160], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([519.6693,  10.6187], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([519.8790,   4.1086], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([391.5814, 188.1295], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([341.7502, 247.9148], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([460.3247, 104.3228], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([347.2159, 241.3204], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([454.7247, 109.8828], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([520.0821,  60.5223], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([519.7446,  19.9888], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([519.6252,   6.0028], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([374.7937, 208.4901], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([438.9352, 129.3815], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([462.2046, 102.8726], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([462.2046, 102.8726], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([326.0553, 267.0823], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([440.7213, 127.1712], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([520.1292,  66.1932], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([519.8510,  33.2131], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([519.6503,   8.2651], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([326.0553, 267.0823], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([326.0553, 267.0823], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([374.3970, 208.9607], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([460.3247, 104.3228], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([504.7247,  93.6127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([519.8687,  35.4149], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([519.6694,   5.6731], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([396.4777, 182.0257], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([454.1901, 110.5347], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([463.8153, 102.4127], device='cuda:0') tensor([0., 0.], device='cuda:0')

# %%
def evaluate_model(model, dataloader):
    model.eval()
    total_loss = 0
    steps = 0
    for inputs, masks, paths in dataloader:
        hidden = None
        loss = 0
        seq_len = inputs.size(1)
        current_input = inputs[:, 0, :].unsqueeze(1)
        for t in range(1, seq_len):
            new_steps = int(sum((inputs[:, t, :2].reshape(-1) != 0).float().to(device))) / 2
            if new_steps == 0:
                break
            steps += new_steps
            prediction, hidden = model(current_input, hidden)
            projection_with_checkpoints = project_to_nearest_with_checkpoints(prediction, paths)
            current_input = (projection_with_checkpoints * masks[:, t, :] + inputs[:, t, :] * (1-masks[:, t, :])).unsqueeze(1)
            loss += torch.norm((projection_with_checkpoints[:, :2] - inputs[:, t, :2]) * 10, dim=1) * (inputs[:, t, :2] != 0)[:, 0]
        total_loss += loss.sum().item()
    print(f'Validation Loss: {total_loss / steps}')

# load model
# model = GRUModel(input_size=6, hidden_size=256, num_layers=2, num_classes=2).to(device)
# model.load_state_dict(torch.load('model.pth'))
for i in [0.9, 0.8, 0.7, 0.6, 0.5, 0]:
    val_mask = generate_masks(val_trajectories_tensor, missing_ratio=i, complete_traj_ratio=0)
    val_dataset = DatasetWithPlans(val_trajectories_tensor, val_mask, val_checkpoints)
    val_dataloader = DataLoader(val_dataset, batch_size=64, shuffle=True)
    evaluate_model(model, val_dataloader)
# Out:
# Validation Loss: 63.79428057733073
# Validation Loss: 46.96636624033158
# Validation Loss: 40.05981302788013
# Validation Loss: 36.19261911833051
# Validation Loss: 33.99255013972077
# Validation Loss: 30.81814166334704

# %%
# # save the model
# torch.save(model.state_dict(), 'gru_trajectory_prediction.pth')
