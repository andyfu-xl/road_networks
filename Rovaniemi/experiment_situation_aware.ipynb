# %%
import sys
import random
import torch
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader, Dataset
import sumolib
import traci
from sumolib import checkBinary
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.data import Data
import sys
import io
from contextlib import redirect_stdout
import matplotlib.pyplot as plt
import pandas as pd
import os
import math
from utils import *


if 'SUMO_HOME' in os.environ:
    print('SUMO_HOME found')
    sys.path.append(os.path.join(os.environ['SUMO_HOME'], 'tools'))

# sumoBinary = checkBinary('sumo-gui')
sumoBinary = checkBinary('sumo')
roadNetwork = "./config/osm.sumocfg"
sumoCmd = [sumoBinary, "-c", roadNetwork, "--start", "--quit-on-end"]
# use gpu if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device: " + str(device))
# Out:
# SUMO_HOME found
# SUMO_HOME found
# Using device: cuda

# %%
planned_path = get_planned_path()
checkpoints = list(planned_path.values())
checkpoints = torch.tensor(checkpoints).float() / 10
# Out:
#  Retrying in 1 seconds
# ***Starting server on port 59101 ***
# Loading net-file from './config/osm.net.xml.gz' ... done (157ms).
# Loading additional-files from './config/osm.poly.xml.gz' ... done (104ms).
# Loading done.
# Simulation version 1.20.0 started with time: 0.00.
# Simulation ended at time: 10431.00
# Reason: TraCI requested termination.
# Performance:
#  Duration: 12.09s
#  TraCI-Duration: 8.04s
#  Real time factor: 863.065
#  UPS: 92862.651001
# Vehicles:
#  Inserted: 3937
#  Running: 0
#  Waiting: 0
# Statistics (avg of 3937):
#  RouteLength: 3678.32
#  Speed: 12.97
#  Duration: 285.07
#  WaitingTime: 12.59
#  TimeLoss: 59.04
#  DepartDelay: 0.59

# %%
def project_to_nearest(prediction, planned_path):
    with torch.no_grad():
        starts = planned_path[:, :-1, :]
        to = planned_path[:, 1:, :]

        prediction = prediction.unsqueeze(1).repeat(1, starts.shape[1], 1)
        ap = prediction - starts
        ab = to - starts
        numerator = torch.einsum('ijk,ijk->ij', ap, ab)
        denominator = torch.einsum('ijk,ijk->ij', ab, ab)
        t = numerator / denominator
        t = torch.nan_to_num(t, nan=0.0)
        t = torch.clamp(t, 0, 1)
        projections = starts + t.unsqueeze(2) * ab
        diff = projections - prediction
        distances = torch.norm(diff, dim=2)
        min_indices = torch.argmin(distances, dim=1)
        projections = projections[range(projections.shape[0]), min_indices]
        return projections, min_indices


def project_to_nearest_with_checkpoints(prediction, planned_path):
    with torch.no_grad():
        starts = planned_path[:, :-1, :]
        to = planned_path[:, 1:, :]

        prediction = prediction.unsqueeze(1).repeat(1, starts.shape[1], 1)
        ap = prediction - starts
        ab = to - starts
        numerator = torch.einsum('ijk,ijk->ij', ap, ab)
        denominator = torch.einsum('ijk,ijk->ij', ab, ab)
        t = numerator / denominator
        t = torch.nan_to_num(t, nan=0.0)
        t = torch.clamp(t, 0, 1)
        projections = starts + t.unsqueeze(2) * ab
        diff = projections - prediction
        distances = torch.norm(diff, dim=2)
        min_indices = torch.argmin(distances, dim=1)
        projections = projections[range(projections.shape[0]), min_indices]
        next_checkpoint = to[range(to.shape[0]), min_indices]
        pad_to = F.pad(to, (0, 0, 1, 0), value=0)
        next_next_checkpoint = pad_to[range(to.shape[0]), min_indices + 1]
        projections_with_checkpoints = torch.cat((projections, next_checkpoint, next_next_checkpoint), dim=1)
        return projections_with_checkpoints

# %%
# Example DataFrame loading
df = pd.read_csv('rovaniemi_trajectories.csv')
num_cols = df.shape[1]
position_indices = [i for i in range(num_cols) if i % 4 == 1 or i % 4 == 2]
position_df = df.iloc[:, position_indices]
position_array = position_df.to_numpy()
sequence_length = len(position_indices) // 2
tensor_list = []

for row in position_array:
    reshaped_tensor = torch.tensor(row.reshape(sequence_length, 2))
    tensor_list.append(reshaped_tensor)

all_trajectories_tensor = torch.stack(tensor_list).float() / 10

next_checkpoint = torch.zeros_like(all_trajectories_tensor)
next_next_checkpoint = torch.zeros_like(all_trajectories_tensor)
checkpoints_pad_1 = F.pad(checkpoints, (0, 0, 1, 0))
for i in range(all_trajectories_tensor.shape[1]):
    _, min_indices = project_to_nearest(all_trajectories_tensor[:, i], checkpoints)
    next_checkpoint[:, i] = checkpoints_pad_1[range(checkpoints.shape[0]), min_indices+1]
    next_next_checkpoint[:, i] = checkpoints_pad_1[range(checkpoints.shape[0]), min_indices+2]

all_trajectories_tensor = torch.cat((all_trajectories_tensor, next_checkpoint, next_next_checkpoint), dim=2)

# %%
# break trajectories into 1000 by 1000 cells
trajectory_list = []
checkpoints_list = []
for i in range(all_trajectories_tensor.shape[0]):
    trajectory = all_trajectories_tensor[i]
    path = checkpoints[i]
    modif = ((trajectory[0, :2] // 100) * 100 - 10).repeat(1, 3)
    trajectory_to_add = []
    next_trajectory_to_add = []
    for j in range(trajectory.shape[0]):
        if trajectory[j:, :2].max() == 0:
            break
        trajectory_j = (trajectory[j] - modif).squeeze()
        # if the vehicle move out of the current cell
        if trajectory_j[0] < 0 or trajectory_j[1] < 0 or trajectory_j[0] > 120 or trajectory_j[1] > 120:
            # we first add all the points in the current cell
            trajectory_list.append(torch.stack(trajectory_to_add))
            # then we add checkpoints
            checkpoints_list.append(path-modif.squeeze()[:2])

            # we reset the to add list
            trajectory_to_add = []
            modif = ((trajectory[j, :2] // 100) * 100 - 10).repeat(1, 3)
            # reset the to_add list, adding a part of the history to the new trajectory
            if j != trajectory.shape[0] - 1:
                rewind = 0
                while True:
                    trajectory_k = (trajectory[j - rewind] - modif).squeeze()
                    if trajectory_k[0] < 0 or trajectory_k[0] > 120 or trajectory_k[1] < 0 or trajectory_k[1] > 120:
                        rewind += 1
                    else:
                        break
                trajectory_to_add = trajectory_to_add[:-rewind]

        else:
            trajectory_to_add.append(trajectory_j)

# %%
checkpoints = torch.stack(checkpoints_list)
def pad_tensors(tensors):
    max_length = max([t.shape[0] for t in tensors])
    padded_tensors = []
    for tensor in tensors:
        padded_tensor = F.pad(tensor, (0, 0, 0, max_length - tensor.shape[0]))
        padded_tensors.append(padded_tensor)
    return torch.stack(padded_tensors)

all_trajectories_tensor = pad_tensors(trajectory_list)

# %%
def missing(x, y, z, p):
    return torch.tensor(np.repeat(np.random.rand(x * y) < p, z).reshape(x, y, z)).float()

def generate_masks(tensors, min_mask_ratio=0.0, max_mask_ratio=0.1, missing_ratio=0.6, complete_traj_ratio=0.75):
    initial_masks = missing(tensors.shape[0], tensors.shape[1], tensors.shape[2], missing_ratio)
    masks = []
    for initial_mask in initial_masks:
        if np.random.rand() < complete_traj_ratio:
            masks.append(torch.zeros_like(initial_mask).tolist())
            continue
        seq_length = initial_mask.shape[0]
        mask_start = np.random.randint(int(seq_length * min_mask_ratio), int(seq_length * max_mask_ratio))
        mask = torch.zeros_like(initial_mask)
        mask[:, :mask_start] = 1
        mask = initial_mask * mask
        mask[0] = 0
        mask[1] = 0
        masks.append(mask.tolist())
    return torch.tensor(masks)

# split the data into training and validation sets
# because the data is randomly generated, we don't need to shuffle it
train_ratio = 0.8
train_size = int(train_ratio * all_trajectories_tensor.shape[0])
train_trajectories_tensor = all_trajectories_tensor[:train_size]
val_trajectories_tensor = all_trajectories_tensor[train_size:]

train_checkpoints = checkpoints[:train_size]
val_checkpoints = checkpoints[train_size:]

train_mask = generate_masks(train_trajectories_tensor)

class DatasetWithPlans(Dataset):
    def __init__(self, tensor, input_mask, checkpoints):
        self.tensor = tensor.float().to(device)
        self.input_mask = input_mask.float().to(device)
        self.checkpoints = checkpoints.float().to(device)
    def __len__(self):
        return len(self.tensor)
    def __getitem__(self, idx):
        return self.tensor[idx], self.input_mask[idx], self.checkpoints[idx]
    
train_dataset = DatasetWithPlans(train_trajectories_tensor, train_mask, train_checkpoints)

# %%
class GRUModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(GRUModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
        self.fc1 = nn.Linear(hidden_size, int(hidden_size/2))
        self.fc2 = nn.Linear(int(hidden_size/2), num_classes)
        self.relu = nn.ReLU()
    
    def forward(self, x, h0=None):
        if h0 is None:
            h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        out, hidden = self.gru(x, h0)  
        out = self.fc1(out[:, -1, :])
        out = self.relu(out)
        out = self.fc2(out)
        return out, hidden

class CustomMSE(nn.Module):
    def __init__(self):
        super(CustomMSE, self).__init__()

    def forward(self, output, target):
        # where target is 0
        mask = (target != 0).float().to(device)
        mse = torch.mean(((output - target) ** 2) * mask)
        directional_diff = torch.mean(torch.abs(torch.atan2(output[:, 1], output[:, 0]) - torch.atan2(target[:, 1], target[:, 0])))
        return mse + directional_diff

# %%
def train_model(model, dataloader, epochs, optimizer, criterion):
    model.train()
    for epoch in range(epochs):
        total_loss = 0
        for inputs, masks, planned_path in dataloader:
            optimizer.zero_grad()
            hidden = None
            loss = 0
            # Autoregressive prediction
            # Start with the first input and predict each subsequent step
            seq_len = inputs.size(1)
            current_input = inputs[:, 0, :].unsqueeze(1)
            for t in range(1, seq_len):
                prediction, hidden = model(current_input, hidden)

                previous_input = inputs[:, t-1, :2]
                if epoch > 8:
                    projection_with_checkpoints = project_to_nearest_with_checkpoints(prediction, planned_path)
                    current_input = (projection_with_checkpoints * masks[:, t, :] + inputs[:, t, :] * (1-masks[:, t, :])).unsqueeze(1)
                else:
                    current_input = inputs[:, t, :].unsqueeze(1)
                if t > 1:
                    loss += criterion(prediction - previous_input, inputs[:, t, :2]-previous_input) #(current_input-previous_input).squeeze(1))
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
 
        print(f'Epoch {epoch+1}, Loss: {total_loss / len(dataloader)}')
        # if epoch >= 20 and total_loss / len(dataloader) < 2000:
        #     break

train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)

model = GRUModel(input_size=6, hidden_size=256, num_layers=2, num_classes=2).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = CustomMSE()
train_model(model, train_dataloader, 20, optimizer, criterion)
# Out:
# Epoch 1, Loss: 91378.32451235702
# Epoch 2, Loss: 7747.486316955167
# Epoch 3, Loss: 4553.354701222937
# Epoch 4, Loss: 4321.49547302645
# Epoch 5, Loss: 4105.543350119996
# Epoch 6, Loss: 3699.558285781761
# Epoch 7, Loss: 3527.3259468826595
# Epoch 8, Loss: 3627.388153275633
# Epoch 9, Loss: 3330.6210889629288
# Epoch 10, Loss: 5547.016051049326
# Epoch 11, Loss: 3955.472239774816
# Epoch 12, Loss: 3770.2608778211807
# Epoch 13, Loss: 4137.996933083129
# Epoch 14, Loss: 4095.3952030356413
# Epoch 15, Loss: 3854.801416334763
# Epoch 16, Loss: 4000.2583901399103
# Epoch 17, Loss: 3708.1426674836603
# Epoch 18, Loss: 3553.5977703418607
# Epoch 19, Loss: 3446.2509175219566
# Epoch 20, Loss: 3261.9979431551264

# %%
def checkModel(model, inputs, masks, paths):
    model.eval()
    with torch.no_grad():
        hidden = None
        seq_len = inputs.size(1)
        current_input = inputs[:, 0, :].unsqueeze(1)
        for t in range(1, seq_len):
            prediction, hidden = model(current_input, hidden)
            projection_with_checkpoints = project_to_nearest_with_checkpoints(prediction, paths)
            current_input = (projection_with_checkpoints * masks[:, t, :] + inputs[:, t, :] * (1-masks[:, t, :])).unsqueeze(1)
            print(projection_with_checkpoints[0][:2]*10, inputs[:, t, :][0][:2]*10)

# get the first batch in dataloader
val_mask = generate_masks(val_trajectories_tensor, missing_ratio=0.5, complete_traj_ratio=0)
val_dataset = DatasetWithPlans(val_trajectories_tensor, val_mask, val_checkpoints)
val_dataloader = DataLoader(val_dataset, batch_size=64, shuffle=True)
inputs, masks, paths = next(iter(val_dataloader))

checkModel(model, inputs, masks, paths)
# Out:
# tensor([-15.4651, 189.8609], device='cuda:0') tensor([253.0347, 157.6392], device='cuda:0')
# tensor([278.4694, 153.8990], device='cuda:0') tensor([278.3868, 153.9111], device='cuda:0')
# tensor([299.9497, 150.7313], device='cuda:0') tensor([302.5504, 150.3306], device='cuda:0')
# tensor([304.4930, 150.0313], device='cuda:0') tensor([327.2165, 146.5476], device='cuda:0')
# tensor([304.5288, 150.0258], device='cuda:0') tensor([352.4036, 142.6964], device='cuda:0')
# tensor([350.8958, 142.9269], device='cuda:0') tensor([375.8731, 139.1299], device='cuda:0')
# tensor([348.6491, 143.2704], device='cuda:0') tensor([399.6039, 135.6370], device='cuda:0')
# tensor([411.4608, 133.8916], device='cuda:0') tensor([424.9741, 131.9026], device='cuda:0')
# tensor([435.9323, 130.2896], device='cuda:0') tensor([448.8678, 128.3856], device='cuda:0')
# tensor([436.3769, 130.2242], device='cuda:0') tensor([473.7274, 124.7298], device='cuda:0')
# tensor([438.5770, 129.9003], device='cuda:0') tensor([497.7267, 121.2016], device='cuda:0')
# tensor([522.7164, 116.6835], device='cuda:0') tensor([522.8845, 116.6531], device='cuda:0')
# tensor([533.6609, 114.7048], device='cuda:0') tensor([546.5927, 111.7180], device='cuda:0')
# tensor([558.6317, 108.8635], device='cuda:0') tensor([570.2206, 105.9700], device='cuda:0')
# tensor([587.0654, 101.6180], device='cuda:0') tensor([594.4119,  99.7627], device='cuda:0')
# tensor([600.9111,  98.1780], device='cuda:0') tensor([614.3280,  95.0233], device='cuda:0')
# tensor([630.5068,  92.4530], device='cuda:0') tensor([632.8729,  92.2819], device='cuda:0')
# tensor([646.6338,  92.0933], device='cuda:0') tensor([647.6651,  92.1345], device='cuda:0')
# tensor([657.4069,  92.5263], device='cuda:0') tensor([661.7868,  92.8841], device='cuda:0')
# tensor([670.1578,  93.5682], device='cuda:0') tensor([676.5634,  95.0520], device='cuda:0')
# tensor([674.0439,  94.4178], device='cuda:0') tensor([692.3102,  99.5836], device='cuda:0')
# tensor([675.1305,  94.6780], device='cuda:0') tensor([708.7457, 105.2916], device='cuda:0')
# tensor([674.7792,  94.5939], device='cuda:0') tensor([725.0552, 114.6608], device='cuda:0')
# tensor([673.7474,  94.3468], device='cuda:0') tensor([742.3624, 126.1483], device='cuda:0')
# tensor([672.5806,  94.0675], device='cuda:0') tensor([757.1750, 138.3168], device='cuda:0')
# tensor([770.2168, 153.1572], device='cuda:0') tensor([768.6591, 151.3552], device='cuda:0')
# tensor([771.9544, 155.1735], device='cuda:0') tensor([777.0651, 161.1141], device='cuda:0')
# tensor([771.1887, 154.2834], device='cuda:0') tensor([784.8456, 170.1564], device='cuda:0')
# tensor([791.7740, 178.2013], device='cuda:0') tensor([793.1381, 179.7856], device='cuda:0')
# tensor([797.1648, 184.4610], device='cuda:0') tensor([800.8054, 188.6885], device='cuda:0')
# tensor([799.0355, 186.6333], device='cuda:0') tensor([807.8772, 196.9003], device='cuda:0')
# tensor([800.1935, 187.9780], device='cuda:0') tensor([816.4032, 206.8004], device='cuda:0')
# tensor([800.9233, 188.8254], device='cuda:0') tensor([822.9822, 214.4399], device='cuda:0')
# tensor([801.4156, 189.3971], device='cuda:0') tensor([827.1796, 219.3141], device='cuda:0')
# tensor([830.2867, 222.9219], device='cuda:0') tensor([830.3296, 222.9716], device='cuda:0')
# tensor([828.9741, 221.3977], device='cuda:0') tensor([831.8088, 224.6893], device='cuda:0')
# tensor([824.9848, 216.7655], device='cuda:0') tensor([832.0392, 224.9568], device='cuda:0')
# tensor([826.5461, 218.5784], device='cuda:0') tensor([832.1582, 225.0950], device='cuda:0')
# tensor([823.9853, 215.6048], device='cuda:0') tensor([833.1702, 226.2699], device='cuda:0')
# tensor([827.9278, 220.1828], device='cuda:0') tensor([834.7098, 228.0576], device='cuda:0')
# tensor([825.3937, 217.2402], device='cuda:0') tensor([837.5232, 231.3216], device='cuda:0')
# tensor([834.9358, 228.3204], device='cuda:0') tensor([841.8597, 236.2608], device='cuda:0')
# tensor([839.2783, 233.3210], device='cuda:0') tensor([847.1320, 242.2659], device='cuda:0')
# tensor([842.7855, 237.3154], device='cuda:0') tensor([853.6713, 249.6783], device='cuda:0')
# tensor([837.8091, 231.6475], device='cuda:0') tensor([860.8920, 258.6339], device='cuda:0')
# tensor([862.2621, 260.3649], device='cuda:0') tensor([868.3191, 268.0205], device='cuda:0')
# tensor([861.6741, 259.6219], device='cuda:0') tensor([875.4846, 277.0773], device='cuda:0')
# tensor([878.6959, 281.1358], device='cuda:0') tensor([883.4787, 287.1812], device='cuda:0')
# tensor([885.5029, 289.7393], device='cuda:0') tensor([891.2543, 297.0090], device='cuda:0')
# tensor([889.3719, 294.6295], device='cuda:0') tensor([899.1498, 306.9897], device='cuda:0')
# tensor([888.5802, 293.6287], device='cuda:0') tensor([906.8048, 316.6663], device='cuda:0')
# tensor([913.2017, 324.7525], device='cuda:0') tensor([914.0668, 325.8461], device='cuda:0')
# tensor([919.4849, 332.6953], device='cuda:0') tensor([919.6753, 332.9356], device='cuda:0')
# tensor([921.2997, 334.9893], device='cuda:0') tensor([925.5444, 340.3573], device='cuda:0')
# tensor([930.7538, 344.4494], device='cuda:0') tensor([934.5197, 346.0538], device='cuda:0')
# tensor([931.1572, 344.6858], device='cuda:0') tensor([947.0490, 348.7351], device='cuda:0')
# tensor([930.1428, 344.0915], device='cuda:0') tensor([953.3136, 355.7756], device='cuda:0')
# tensor([929.2242, 343.5533], device='cuda:0') tensor([954.8245, 364.0273], device='cuda:0')
# tensor([960.0299, 370.1440], device='cuda:0') tensor([959.8798, 369.9662], device='cuda:0')
# tensor([965.0617, 375.3244], device='cuda:0') tensor([966.3007, 376.4628], device='cuda:0')
# tensor([972.8442, 382.4744], device='cuda:0') tensor([974.8248, 384.2941], device='cuda:0')
# tensor([981.9518, 390.8418], device='cuda:0') tensor([982.6337, 391.4682], device='cuda:0')
# tensor([987.3005, 395.7558], device='cuda:0') tensor([990.3894, 398.5941], device='cuda:0')
# tensor([995.8805, 404.0800], device='cuda:0') tensor([996.9492, 405.1599], device='cuda:0')
# tensor([1006.1557,  414.4614], device='cuda:0') tensor([1004.0329,  412.3169], device='cuda:0')
# tensor([1014.9490,  423.3455], device='cuda:0') tensor([1010.5780,  418.9294], device='cuda:0')
# tensor([1021.3174,  429.7796], device='cuda:0') tensor([1017.2388,  425.6589], device='cuda:0')
# tensor([1027.0110,  435.2314], device='cuda:0') tensor([1023.0585,  431.5385], device='cuda:0')
# tensor([1032.1995,  439.2570], device='cuda:0') tensor([1028.0383,  436.1174], device='cuda:0')
# tensor([1036.7999,  442.0100], device='cuda:0') tensor([1032.6614,  439.5511], device='cuda:0')
# tensor([1036.7999,  442.0100], device='cuda:0') tensor([1037.0502,  442.0529], device='cuda:0')
# tensor([1038.0200,  442.2200], device='cuda:0') tensor([1041.6534,  440.8334], device='cuda:0')
# tensor([1038.6000,  442.1446], device='cuda:0') tensor([1048.1226,  439.3292], device='cuda:0')
# tensor([1052.7919,  440.1808], device='cuda:0') tensor([1055.7928,  442.0639], device='cuda:0')
# tensor([1058.7350,  445.0619], device='cuda:0') tensor([1060.8948,  451.1909], device='cuda:0')
# tensor([1060.8799,  450.8600], device='cuda:0') tensor([1059.5844,  458.2465], device='cuda:0')
# tensor([1060.7098,  455.0999], device='cuda:0') tensor([1059.1128,  465.3815], device='cuda:0')
# tensor([1060.0800,  457.2400], device='cuda:0') tensor([1063.1448,  474.3626], device='cuda:0')
# tensor([1069.7756,  483.2335], device='cuda:0') tensor([1069.3463,  482.6590], device='cuda:0')
# tensor([1072.9324,  487.4565], device='cuda:0') tensor([1075.4282,  490.5638], device='cuda:0')
# tensor([1085.3383,  501.7087], device='cuda:0') tensor([1082.3718,  498.3728], device='cuda:0')
# tensor([1092.4042,  509.6554], device='cuda:0') tensor([1088.8153,  505.6194], device='cuda:0')
# tensor([1100.2781,  518.5107], device='cuda:0') tensor([1095.0079,  512.5839], device='cuda:0')
# tensor([1108.8650,  528.5914], device='cuda:0') tensor([1101.8042,  520.2272], device='cuda:0')
# tensor([1109.9779,  531.9688], device='cuda:0') tensor([1108.5598,  527.9922], device='cuda:0')
# tensor([1109.9799,  531.8700], device='cuda:0') tensor([1110.8376,  537.1750], device='cuda:0')
# tensor([1115.5414,  542.8260], device='cuda:0') tensor([1117.0581,  544.5377], device='cuda:0')
# tensor([1124.5315,  552.9717], device='cuda:0') tensor([1123.3083,  551.5915], device='cuda:0')
# tensor([1132.5139,  561.9803], device='cuda:0') tensor([1129.6356,  558.7322], device='cuda:0')
# tensor([1138.6943,  567.4847], device='cuda:0') tensor([1136.3922,  566.3569], device='cuda:0')
# tensor([1021.9850,  525.0776], device='cuda:0') tensor([1143.1085,  574.0750], device='cuda:0')
# tensor([1017.2435,  523.3548], device='cuda:0') tensor([1149.7125,  581.7504], device='cuda:0')
# tensor([1016.6792,  523.1497], device='cuda:0') tensor([1156.0403,  589.1458], device='cuda:0')
# tensor([1016.6405,  523.1357], device='cuda:0') tensor([1162.7618,  597.1213], device='cuda:0')
# tensor([1016.6078,  523.1238], device='cuda:0') tensor([1169.3882,  604.9843], device='cuda:0')
# tensor([959.6990, 502.4456], device='cuda:0') tensor([1175.0830,  611.7416], device='cuda:0')
# tensor([702.4365, 408.9677], device='cuda:0') tensor([1181.3113,  619.1320], device='cuda:0')
# tensor([763.6293, 431.2025], device='cuda:0') tensor([1187.4164,  626.3760], device='cuda:0')
# tensor([775.0676, 435.3586], device='cuda:0') tensor([1193.3093,  633.3688], device='cuda:0')
# tensor([767.3799, 432.5653], device='cuda:0') tensor([1199.1693,  640.3220], device='cuda:0')
# tensor([767.4924, 432.6062], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([767.4706, 432.5983], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([258.7577, 156.7976], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([279.9040, 153.6881], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([270.3698, 155.0901], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([288.3293, 152.4491], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([276.0403, 154.2562], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([273.9887, 154.5579], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([271.7752, 154.8834], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([269.9279, 155.1550], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([290.1001, 152.1888], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([279.2138, 153.7896], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([276.4120, 154.2016], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([293.0553, 151.7542], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([281.9164, 153.3922], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([279.0283, 153.8168], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([276.5446, 154.1821], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([274.7317, 154.4487], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([273.5243, 154.6262], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([272.2340, 154.8159], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([271.0203, 154.9944], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([291.4756, 151.9865], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([280.2398, 153.6387], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([295.8292, 151.3463], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([281.8433, 153.4029], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([296.5318, 151.2430], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([283.0122, 153.2310], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([280.5710, 153.5900], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([278.2741, 153.9277], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([295.8841, 151.3382], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([301.1648, 150.5441], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([303.3929, 150.2008], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([304.3554, 150.0525], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([304.7411, 149.9931], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([304.8891, 149.9703], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([304.9400, 149.9624], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([304.9762, 149.9569], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([281.0955, 153.5129], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([284.4203, 153.0240], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([297.8993, 151.0419], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([302.4524, 150.3457], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([304.2437, 150.0697], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([304.9741, 149.9572], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([305.2161, 149.9199], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([305.2951, 149.9077], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([283.6522, 153.1369], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([302.0402, 150.4092], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([304.4215, 150.0423], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([286.7018, 152.6885], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([302.6060, 150.3221], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([304.8993, 149.9687], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([286.9687, 152.6492], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([303.0717, 150.2503], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([290.6314, 152.1106], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([288.0328, 152.4928], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([285.5727, 152.8545], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([302.3380, 150.3633], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([290.3208, 152.1563], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([305.0457, 149.9462], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([307.5766, 149.5562], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([287.9376, 152.5067], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([289.2025, 152.3207], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([303.4542, 150.1914], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([291.4851, 151.9851], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([305.6734, 149.8494], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([291.5451, 151.9763], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([305.4934, 149.8772], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([307.9435, 149.4997], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([288.6138, 152.4073], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([305.2732, 149.9111], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([292.4595, 151.8418], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([290.3510, 152.1519], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([287.9889, 152.4992], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([286.5744, 152.7072], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([285.7726, 152.8251], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([284.8713, 152.9576], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([302.7064, 150.3066], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([306.8323, 149.6709], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([287.9594, 152.5035], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([289.1697, 152.3256], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([303.6432, 150.1622], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([291.5381, 151.9773], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([289.2970, 152.3068], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([304.0585, 150.0983], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([291.7978, 151.9391], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([289.6963, 152.2481], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([304.4136, 150.0435], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([307.9009, 149.5063], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([289.3343, 152.3014], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([306.1465, 149.7766], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([308.4245, 149.4256], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([289.5163, 152.2746], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([305.8579, 149.8210], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([308.0495, 149.4834], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([308.7201, 149.3800], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([308.8539, 149.3595], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([308.8436, 149.3611], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([288.0323, 152.4928], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([305.7705, 149.8345], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([294.0356, 151.6100], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([306.4152, 149.7352], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([293.3242, 151.7146], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([306.5917, 149.7080], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([308.7201, 149.3800], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([309.3863, 149.2780], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([289.1675, 152.3259], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([306.2795, 149.7561], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([294.0789, 151.6037], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([306.6693, 149.6960], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([293.5568, 151.6804], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([306.8146, 149.6736], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([308.8517, 149.3599], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([309.5519, 149.2526], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([309.6670, 149.2350], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([309.6207, 149.2421], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([288.3434, 152.4471], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([306.2936, 149.7539], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([308.2729, 149.4489], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([290.9091, 152.0698], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([293.2962, 151.7188], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([305.9105, 149.8129], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([294.4587, 151.5478], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([307.9668, 149.4961], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([294.3212, 151.5680], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([307.7219, 149.5338], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([294.3152, 151.5689], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([307.6751, 149.5410], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([294.3108, 151.5696], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([293.2493, 151.7256], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([291.0709, 152.0460], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([289.7965, 152.2334], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([289.0681, 152.3405], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([288.2206, 152.4651], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([287.4981, 152.5714], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([304.6280, 150.0105], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([308.5946, 149.3994], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([289.8425, 152.2266], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([306.9991, 149.6452], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([309.1165, 149.3193], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([290.2869, 152.1613], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([292.0270, 151.9054], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([289.2389, 152.3154], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([287.9016, 152.5120], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([287.2429, 152.6089], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([304.1749, 150.0803], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([292.3111, 151.8636], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([290.5883, 152.1170], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([305.0521, 149.9452], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([292.9214, 151.7739], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([291.0512, 152.0489], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([288.6683, 152.3993], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([287.3056, 152.5997], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([286.6375, 152.6979], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([285.8695, 152.8109], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([285.2202, 152.9063], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([284.5661, 153.0025], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([283.9407, 153.0945], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([301.9167, 150.4282], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([289.9552, 152.2101], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([304.9146, 149.9664], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([290.6562, 152.1070], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([288.5349, 152.4189], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([303.3361, 150.2096], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([291.2886, 152.0140], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([305.5488, 149.8687], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([307.9355, 149.5009], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([288.5609, 152.4151], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([305.1444, 149.9310], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([292.3680, 151.8553], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([290.2775, 152.1627], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([287.9903, 152.4990], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([304.0857, 150.0941], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([292.0511, 151.9018], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([290.3331, 152.1545], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([304.7107, 149.9978], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([292.5722, 151.8252], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([306.7217, 149.6879], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([308.9612, 149.3431], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([289.6985, 152.2478], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([291.5317, 151.9782], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([304.9869, 149.9552], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([293.1776, 151.7362], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([307.0281, 149.6407], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([309.2197, 149.3035], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([290.1228, 152.1854], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([292.1477, 151.8876], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([305.3739, 149.8956], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([308.6550, 149.3901], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([310.0462, 149.1769], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([289.9681, 152.2081], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([292.7873, 151.7936], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([290.0338, 152.1985], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([288.7653, 152.3850], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([288.1192, 152.4800], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([287.3862, 152.5878], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([286.7692, 152.6785], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([286.1554, 152.7688], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([303.0777, 150.2494], device='cuda:0') tensor([0., 0.], device='cuda:0')

# %%
def evaluate_model(model, dataloader):
    model.eval()
    total_loss = 0
    steps = 0
    for inputs, masks, paths in dataloader:
        hidden = None
        loss = 0
        seq_len = inputs.size(1)
        current_input = inputs[:, 0, :].unsqueeze(1)
        for t in range(1, seq_len):
            new_steps = int(sum((inputs[:, t, :2].reshape(-1) != 0).float().to(device))) / 2
            if new_steps == 0:
                break
            steps += new_steps
            prediction, hidden = model(current_input, hidden)
            projection_with_checkpoints = project_to_nearest_with_checkpoints(prediction, paths)
            current_input = (projection_with_checkpoints * masks[:, t, :] + inputs[:, t, :] * (1-masks[:, t, :])).unsqueeze(1)
            loss += torch.norm((projection_with_checkpoints[:, :2] - inputs[:, t, :2]) * 10, dim=1) * (inputs[:, t, :2] != 0)[:, 0]
        total_loss += loss.sum().item()
    print(f'Validation Loss: {total_loss / steps}')

# load model
# model = GRUModel(input_size=6, hidden_size=256, num_layers=2, num_classes=2).to(device)
# model.load_state_dict(torch.load('gru_model.pth'))
for i in [0.9, 0.8, 0.7, 0.6, 0.5, 0]:
    val_mask = generate_masks(val_trajectories_tensor, missing_ratio=i, complete_traj_ratio=0)
    val_dataset = DatasetWithPlans(val_trajectories_tensor, val_mask, val_checkpoints)
    val_dataloader = DataLoader(val_dataset, batch_size=64, shuffle=True)
    evaluate_model(model, val_dataloader)
# Out:
# Validation Loss: 89.70970082233242
# Validation Loss: 56.446406791543204
# Validation Loss: 43.39389999637739
# Validation Loss: 36.56842054119573
# Validation Loss: 32.24403993469876
# Validation Loss: 23.07389640588127
