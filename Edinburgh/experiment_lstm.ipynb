# %%
import os
import sys
import random
import torch
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader, Dataset
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.data import Data
import sys
import io
from contextlib import redirect_stdout
import matplotlib.pyplot as plt
import pandas as pd

# use gpu if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device: " + str(device))
# Out:
# Using device: cuda

# %% [markdown]
# ## Prepare the dataset

# %%
# Example DataFrame loading
df = pd.read_csv('edinburgh_trajectories.csv')
num_cols = df.shape[1]
position_indices = [i for i in range(num_cols) if i % 4 == 1 or i % 4 == 2]
position_df = df.iloc[:, position_indices]
position_array = position_df.to_numpy()
sequence_length = len(position_indices) // 2
tensor_list = []

for row in position_array:
    reshaped_tensor = torch.tensor(row.reshape(sequence_length, 2))
    tensor_list.append(reshaped_tensor)

all_trajectories_tensor = torch.stack(tensor_list) / 10

def missing(x, y, z, p):
    return torch.tensor(np.repeat(np.random.rand(x * y) > p, z).reshape(x, y, z)).float()

def generate_masks(tensors, min_mask_ratio=0.2, max_mask_ratio=0.4, missing_ratio=0.5):
    initial_masks = missing(tensors.shape[0], tensors.shape[1], tensors.shape[2], missing_ratio)
    masks = []
    for initial_mask in initial_masks:
        seq_length = initial_mask.shape[0]
        mask_start = np.random.randint(int(seq_length * min_mask_ratio), int(seq_length * max_mask_ratio))
        mask = torch.zeros_like(initial_mask)
        mask[:, :mask_start] = 1
        mask = initial_mask * mask
        mask[0] = 1
        mask[1] = 1
        masks.append(mask.tolist())
    return torch.tensor(masks)

# split the data into training and validation sets
train_ratio = 0.8
train_size = int(train_ratio * all_trajectories_tensor.shape[0])
train_trajectories_tensor = all_trajectories_tensor[:train_size]
val_trajectories_tensor = all_trajectories_tensor[train_size:]

input_mask = generate_masks(val_trajectories_tensor)
outputs_mask = generate_masks(val_trajectories_tensor)

class trainDataset(Dataset):
    def __init__(self, tensor):
        self.tensor = tensor.float().to(device)
    def __len__(self):
        return len(self.tensor)
    def __getitem__(self, idx):
        return self.tensor[idx]

class valDataset(Dataset):
    def __init__(self, inputs, outputs):
        self.inputs = inputs.float().to(device)
        self.outputs = outputs.float().to(device)
    def __len__(self):
        return len(self.inputs)
    def __getitem__(self, idx):
        return self.inputs[idx], self.outputs[idx]

train_dataset = trainDataset(train_trajectories_tensor)
val_inputs = val_trajectories_tensor * input_mask
val_outputs = val_trajectories_tensor * outputs_mask
val_dataset = valDataset(val_inputs, val_outputs)

dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)

# %%
class GRUModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(GRUModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
        self.fc1 = nn.Linear(hidden_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, num_classes)
        self.relu = nn.ReLU()
    
    def forward(self, x, h0=None):
        if h0 is None:
            h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        out, hidden = self.gru(x, h0)  
        out = self.fc1(out[:, -1, :])
        out = self.relu(out)
        out = self.fc2(out)
        out = self.relu(out)
        return out, hidden

class CustomMSE(nn.Module):
    def __init__(self):
        super(CustomMSE, self).__init__()

    def forward(self, output, target):
        # where target is 0
        mask = (target != 0).float().to(device)
        return torch.mean(((output - target) ** 2) * mask)

class CustomMAE(nn.Module):
    def __init__(self):
        super(CustomMAE, self).__init__()

    def forward(self, output, target):
        # where target is 0
        mask = (target != 0).float().to(device)
        return torch.mean(torch.abs(output - target) * mask)

# %%
def train_model(model, dataloader, epochs, optimizer, criterion):
    model.train()
    for epoch in range(epochs):
        total_loss = 0
        for inputs in dataloader:
            optimizer.zero_grad()
            hidden = None
            loss = 0

            # Autoregressive prediction
            # Start with the first input and predict each subsequent step
            seq_len = inputs.size(1)
            current_input = inputs[:, 0, :].unsqueeze(1) # start with the first input step
            for t in range(seq_len):
                prediction, hidden = model(current_input, hidden)
                previous_input = current_input.squeeze(1)
                current_input = inputs[:, t, :].unsqueeze(1)  # next input comes from the ground truth
                loss += criterion(prediction - previous_input, inputs[:, t, :]-previous_input) #(current_input-previous_input).squeeze(1))

            loss.backward()
            optimizer.step()
            total_loss += loss.item()
 
        print(f'Epoch {epoch+1}, Loss: {total_loss / len(dataloader)}')

model = GRUModel(input_size=2, hidden_size=128, num_layers=2, num_classes=2).to(device)
dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = CustomMSE()
train_model(model, dataloader, 20, optimizer, criterion)
# Out:
# Epoch 1, Loss: 1374853.30625
# Epoch 2, Loss: 1025936.3
# Epoch 3, Loss: 572232.4328125
# Epoch 4, Loss: 341278.2828125
# Epoch 5, Loss: 298642.97109375
# Epoch 6, Loss: 291074.603125
# Epoch 7, Loss: 274704.97109375
# Epoch 8, Loss: 161413.95703125
# Epoch 9, Loss: 93920.583203125
# Epoch 10, Loss: 66604.6375
# Epoch 11, Loss: 43209.09755859375
# Epoch 12, Loss: 24345.62099609375
# Epoch 13, Loss: 14646.72861328125
# Epoch 14, Loss: 10175.724462890625
# Epoch 15, Loss: 8986.30107421875
# Epoch 16, Loss: 8526.274243164062
# Epoch 17, Loss: 8314.109497070312
# Epoch 18, Loss: 8250.988818359376
# Epoch 19, Loss: 8037.2176513671875
# Epoch 20, Loss: 8190.695727539062

# %%
def checkModel(model, inputs):
    model.eval()
    with torch.no_grad():
        hidden = None
        seq_len = inputs.size(1)
        current_input = inputs[:, 0, :].unsqueeze(1)
        for t in range(seq_len):
            prediction, hidden = model(current_input, hidden)
            if t > 5:
                current_input = prediction.unsqueeze(1)
            else:
                current_input = inputs[:, t, :].unsqueeze(1)
            print(prediction[2], inputs[:, t, :][2])

# get the first batch in dataloader
inputs = next(iter(dataloader))
checkModel(model, inputs)
# Out:
# tensor([125.6118,  37.2211], device='cuda:0') tensor([102.4169,  58.9456], device='cuda:0')
# tensor([103.6906,  60.2194], device='cuda:0') tensor([102.5772,  59.0529], device='cuda:0')
# tensor([98.0040, 58.3232], device='cuda:0') tensor([102.9224,  59.2840], device='cuda:0')
# tensor([102.6283,  56.1933], device='cuda:0') tensor([103.4246,  59.6078], device='cuda:0')
# tensor([104.6597,  58.3398], device='cuda:0') tensor([104.1253,  60.0554], device='cuda:0')
# tensor([103.7296,  60.0960], device='cuda:0') tensor([104.8880,  60.5386], device='cuda:0')
# tensor([103.8274,  60.6707], device='cuda:0') tensor([105.6763,  61.0188], device='cuda:0')
# tensor([102.9108,  61.0683], device='cuda:0') tensor([106.4125,  61.4672], device='cuda:0')
# tensor([102.0657,  61.4929], device='cuda:0') tensor([107.1865,  61.8727], device='cuda:0')
# tensor([101.3570,  61.9344], device='cuda:0') tensor([108.0303,  62.2991], device='cuda:0')
# tensor([100.7646,  62.3816], device='cuda:0') tensor([108.8609,  62.6971], device='cuda:0')
# tensor([100.2519,  62.8305], device='cuda:0') tensor([109.3207,  62.9073], device='cuda:0')
# tensor([99.7840, 63.2756], device='cuda:0') tensor([109.5886,  62.8429], device='cuda:0')
# tensor([81.5457, 70.4898], device='cuda:0') tensor([106.2614,  44.2872], device='cuda:0')
# tensor([80.7766, 70.4730], device='cuda:0') tensor([106.7897,  43.6576], device='cuda:0')
# tensor([79.9943, 70.4575], device='cuda:0') tensor([107.3100,  43.0137], device='cuda:0')
# tensor([79.1948, 70.4379], device='cuda:0') tensor([107.8434,  42.3535], device='cuda:0')
# tensor([78.3820, 70.4162], device='cuda:0') tensor([108.4384,  41.6172], device='cuda:0')
# tensor([77.5580, 70.3953], device='cuda:0') tensor([108.9877,  40.9312], device='cuda:0')
# tensor([76.7236, 70.3742], device='cuda:0') tensor([109.5855,  40.2145], device='cuda:0')
# tensor([75.8817, 70.3487], device='cuda:0') tensor([110.1881,  39.4896], device='cuda:0')
# tensor([75.0329, 70.3196], device='cuda:0') tensor([110.7660,  38.7904], device='cuda:0')
# tensor([74.1843, 70.2887], device='cuda:0') tensor([111.3366,  38.1000], device='cuda:0')
# tensor([73.3317, 70.2496], device='cuda:0') tensor([111.9214,  37.3924], device='cuda:0')
# tensor([72.4805, 70.2038], device='cuda:0') tensor([112.5110,  36.6791], device='cuda:0')
# tensor([71.6279, 70.1527], device='cuda:0') tensor([113.0706,  36.0021], device='cuda:0')
# tensor([70.7740, 70.0863], device='cuda:0') tensor([113.6725,  35.2738], device='cuda:0')
# tensor([69.9233, 70.0111], device='cuda:0') tensor([114.2085,  34.6253], device='cuda:0')
# tensor([69.0702, 69.9186], device='cuda:0') tensor([114.5057,  34.2658], device='cuda:0')
# tensor([68.2212, 69.8151], device='cuda:0') tensor([114.5335,  34.2321], device='cuda:0')
# tensor([67.3734, 69.6971], device='cuda:0') tensor([114.5379,  34.2267], device='cuda:0')
# tensor([66.5218, 69.5610], device='cuda:0') tensor([114.5390,  34.2254], device='cuda:0')
# tensor([65.6655, 69.4088], device='cuda:0') tensor([114.5392,  34.2252], device='cuda:0')
# tensor([64.8023, 69.2333], device='cuda:0') tensor([114.5392,  34.2252], device='cuda:0')
# tensor([63.9335, 69.0409], device='cuda:0') tensor([114.6476,  34.0749], device='cuda:0')
# tensor([63.0538, 68.8246], device='cuda:0') tensor([114.8073,  33.8070], device='cuda:0')
# tensor([62.1624, 68.5884], device='cuda:0') tensor([114.8073,  33.8070], device='cuda:0')
# tensor([61.2565, 68.3294], device='cuda:0') tensor([114.8073,  33.8070], device='cuda:0')
# tensor([60.3416, 68.0473], device='cuda:0') tensor([114.8420,  33.5779], device='cuda:0')
# tensor([59.4139, 67.7447], device='cuda:0') tensor([114.7184,  33.1672], device='cuda:0')
# tensor([58.4663, 67.4105], device='cuda:0') tensor([114.2799,  32.7464], device='cuda:0')
# tensor([57.5042, 67.0537], device='cuda:0') tensor([113.6911,  32.2679], device='cuda:0')
# tensor([56.5263, 66.6731], device='cuda:0') tensor([113.0106,  31.7148], device='cuda:0')
# tensor([55.5299, 66.2608], device='cuda:0') tensor([112.3546,  31.1816], device='cuda:0')
# tensor([54.5187, 65.8235], device='cuda:0') tensor([111.6428,  30.6031], device='cuda:0')
# tensor([53.4933, 65.3590], device='cuda:0') tensor([110.9082,  30.0060], device='cuda:0')
# tensor([52.4565, 64.8661], device='cuda:0') tensor([110.2378,  29.4611], device='cuda:0')
# tensor([51.4138, 64.3478], device='cuda:0') tensor([109.5278,  28.8840], device='cuda:0')
# tensor([50.3653, 63.8060], device='cuda:0') tensor([108.8437,  28.3280], device='cuda:0')
# tensor([49.3166, 63.2397], device='cuda:0') tensor([108.1209,  27.7406], device='cuda:0')
# tensor([48.2727, 62.6509], device='cuda:0') tensor([107.3926,  27.1486], device='cuda:0')
# tensor([47.2399, 62.0435], device='cuda:0') tensor([106.6676,  26.5594], device='cuda:0')
# tensor([46.2233, 61.4162], device='cuda:0') tensor([106.0071,  26.0226], device='cuda:0')
# tensor([45.2243, 60.7723], device='cuda:0') tensor([105.2861,  25.4370], device='cuda:0')
# tensor([44.2528, 60.1189], device='cuda:0') tensor([104.5633,  24.8503], device='cuda:0')
# tensor([43.3124, 59.4523], device='cuda:0') tensor([103.8773,  24.2944], device='cuda:0')
# tensor([42.4044, 58.7748], device='cuda:0') tensor([103.2189,  23.7609], device='cuda:0')
# tensor([41.5356, 58.0903], device='cuda:0') tensor([102.5683,  23.2336], device='cuda:0')
# tensor([40.7031, 57.4006], device='cuda:0') tensor([101.8515,  22.6527], device='cuda:0')
# tensor([39.9147, 56.7118], device='cuda:0') tensor([101.1584,  22.0819], device='cuda:0')
# tensor([39.1707, 56.0226], device='cuda:0') tensor([100.4689,  21.5039], device='cuda:0')
# tensor([38.4748, 55.3400], device='cuda:0') tensor([99.8379, 20.9750], device='cuda:0')
# tensor([37.8241, 54.6604], device='cuda:0') tensor([99.1584, 20.4054], device='cuda:0')
# tensor([37.2180, 53.9919], device='cuda:0') tensor([98.5096, 19.8615], device='cuda:0')
# tensor([36.6595, 53.3348], device='cuda:0') tensor([98.0156, 19.4592], device='cuda:0')
# tensor([36.1427, 52.6873], device='cuda:0') tensor([97.3160, 19.2675], device='cuda:0')
# tensor([35.6694, 52.0568], device='cuda:0') tensor([96.7968, 19.8535], device='cuda:0')
# tensor([35.2381, 51.4451], device='cuda:0') tensor([96.4324, 20.5907], device='cuda:0')
# tensor([34.8507, 50.8540], device='cuda:0') tensor([96.0106, 21.4437], device='cuda:0')
# tensor([34.5069, 50.2859], device='cuda:0') tensor([95.6315, 22.2106], device='cuda:0')
# tensor([34.1986, 49.7383], device='cuda:0') tensor([95.3872, 22.7125], device='cuda:0')
# tensor([33.9263, 49.2131], device='cuda:0') tensor([95.2557, 23.4384], device='cuda:0')
# tensor([33.6895, 48.7090], device='cuda:0') tensor([95.8249, 24.0380], device='cuda:0')
# tensor([33.4848, 48.2285], device='cuda:0') tensor([96.5326, 24.5451], device='cuda:0')
# tensor([33.3164, 47.7747], device='cuda:0') tensor([97.2155, 25.0289], device='cuda:0')
# tensor([33.1758, 47.3414], device='cuda:0') tensor([97.8845, 25.5441], device='cuda:0')
# tensor([33.0607, 46.9290], device='cuda:0') tensor([98.0102, 26.3747], device='cuda:0')
# tensor([32.9699, 46.5332], device='cuda:0') tensor([97.4561, 27.1224], device='cuda:0')
# tensor([32.9039, 46.1591], device='cuda:0') tensor([96.6463, 27.1136], device='cuda:0')
# tensor([32.8574, 45.8008], device='cuda:0') tensor([95.9812, 26.6220], device='cuda:0')
# tensor([32.8292, 45.4606], device='cuda:0') tensor([95.2156, 26.0726], device='cuda:0')
# tensor([32.8171, 45.1347], device='cuda:0') tensor([94.3812, 26.0168], device='cuda:0')
# tensor([32.8234, 44.8240], device='cuda:0') tensor([93.5108, 25.8529], device='cuda:0')
# tensor([32.8436, 44.5263], device='cuda:0') tensor([92.7327, 25.5084], device='cuda:0')
# tensor([32.8745, 44.2396], device='cuda:0') tensor([91.9570, 25.1550], device='cuda:0')
# tensor([32.9129, 43.9636], device='cuda:0') tensor([91.0972, 24.7631], device='cuda:0')
# tensor([32.9587, 43.6944], device='cuda:0') tensor([90.3420, 24.4193], device='cuda:0')
# tensor([33.0128, 43.4344], device='cuda:0') tensor([89.4928, 24.0362], device='cuda:0')
# tensor([33.0697, 43.1823], device='cuda:0') tensor([88.7197, 23.6840], device='cuda:0')
# tensor([33.1307, 42.9381], device='cuda:0') tensor([87.8591, 23.2883], device='cuda:0')
# tensor([33.1944, 42.6994], device='cuda:0') tensor([87.0618, 22.9244], device='cuda:0')
# tensor([33.2629, 42.4684], device='cuda:0') tensor([86.3127, 22.5831], device='cuda:0')
# tensor([33.3307, 42.2417], device='cuda:0') tensor([85.4638, 22.1955], device='cuda:0')
# tensor([33.3988, 42.0198], device='cuda:0') tensor([84.6932, 21.8444], device='cuda:0')
# tensor([33.4713, 41.8041], device='cuda:0') tensor([83.9208, 21.4924], device='cuda:0')
# tensor([33.5410, 41.5898], device='cuda:0') tensor([83.2843, 21.0031], device='cuda:0')
# tensor([33.6079, 41.3780], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([33.6727, 41.1670], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([33.7355, 40.9581], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([33.7952, 40.7498], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([33.8514, 40.5425], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([33.9050, 40.3365], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([33.9541, 40.1313], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([33.9987, 39.9243], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([34.0406, 39.7180], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([34.0800, 39.5119], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([34.1194, 39.3048], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([34.1553, 39.0967], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([34.1885, 38.8877], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([34.2241, 38.6794], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([34.2555, 38.4691], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([34.2878, 38.2614], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([34.3198, 38.0524], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([34.3500, 37.8430], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([34.3767, 37.6317], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([34.4023, 37.4212], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([34.4277, 37.2087], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([34.4537, 36.9984], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([34.4832, 36.7899], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([34.5150, 36.5823], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([34.5493, 36.3759], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([34.5868, 36.1716], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([34.6296, 35.9700], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([34.6747, 35.7692], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([34.7238, 35.5728], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([34.7794, 35.3811], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([34.8388, 35.1930], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([34.9082, 35.0123], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([34.9872, 34.8356], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.0733, 34.6661], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.1680, 34.5013], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.2731, 34.3435], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.3855, 34.1891], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.5070, 34.0452], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.6407, 33.9093], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.7853, 33.7800], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.9417, 33.6603], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([36.1070, 33.5464], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([36.2831, 33.4451], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([36.4698, 33.3495], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([36.6638, 33.2608], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([36.8695, 33.1831], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([37.0852, 33.1146], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([37.3131, 33.0528], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([37.5539, 33.0015], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([37.8028, 32.9586], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([38.0585, 32.9220], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([38.3204, 32.8957], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([38.5924, 32.8750], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([38.8701, 32.8637], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([39.1557, 32.8619], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([39.4441, 32.8683], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([39.7366, 32.8834], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([40.0321, 32.9067], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([40.3337, 32.9391], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([40.6381, 32.9772], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([40.9455, 33.0235], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([41.2521, 33.0768], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([41.5641, 33.1417], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([41.8813, 33.2134], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.1994, 33.2912], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.5193, 33.3763], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.8364, 33.4689], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([43
device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([41.9926, 55.9440], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.1634, 56.2118], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.3142, 56.4740], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.4441, 56.7287], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.5543, 56.9751], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.6403, 57.2090], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.7025, 57.4301], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.7414, 57.6352], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.7566, 57.8245], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.7479, 57.9930], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.7105, 58.1431], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.6495, 58.2711], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.5569, 58.3734], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.4420, 58.4527], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.3075, 58.5124], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.1510, 58.5466], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([41.9711, 58.5578], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([41.7729, 58.5455], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([41.5575, 58.5133], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([41.3296, 58.4623], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([41.0886, 58.3945], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([40.8392, 58.3072], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([40.5769, 58.1999], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([40.3073, 58.0792], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([40.0336, 57.9423], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([39.7549, 57.7909], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([39.4736, 57.6263], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([39.1962, 57.4558], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([38.9215, 57.2749], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([38.6485, 57.0838], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([38.3771, 56.8831], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([38.1142, 56.6802], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([37.8600, 56.4732], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([37.6145, 56.2620], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([37.3803, 56.0522], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([37.1574, 55.8402], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([36.9446, 55.6262], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([36.7426, 55.4139], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([36.5567, 55.2042], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([36.3838, 54.9988], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([36.2247, 54.7975], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([36.0786, 54.5997], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.9422, 54.4038], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.8189, 54.2142], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.7076, 54.0288], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.6103, 53.8503], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.5286, 53.6793], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.4624, 53.5168], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.4079, 53.3601], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.3676, 53.2130], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.3422, 53.0732], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.3316, 52.9437], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.3335, 52.8234], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.3502, 52.7143], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.3781, 52.6115], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.4156, 52.5194], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.4661, 52.4360], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.5299, 52.3649], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.6051, 52.2998], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.6937, 52.2495], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.7935, 52.2093], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([35.9046, 52.1803], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([36.0259, 52.1610], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([36.1564, 52.1515], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([36.2973, 52.1540], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([36.4496, 52.1692], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([36.6115, 52.1928], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([36.7780, 52.2270], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([36.9532, 52.2721], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([37.1380, 52.3311], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([37.3320, 52.4014], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([37.5264, 52.4796], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([37.7349, 52.5746], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([37.9471, 52.6786], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([38.1640, 52.7949], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([38.3870, 52.9231], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([38.6143, 53.0621], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([38.8435, 53.2123], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([39.0742, 53.3719], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([39.3061, 53.5411], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([39.5409, 53.7232], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([39.7726, 53.9096], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([40.0004, 54.1088], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([40.2261, 54.3128], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([40.4464, 54.5254], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([40.6635, 54.7440], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([40.8727, 54.9664], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([41.0755, 55.1956], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([41.2649, 55.4233], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([41.4434, 55.6547], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([41.6122, 55.8887], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([41.7667, 56.1193], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([41.9080, 56.3451], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.0296, 56.5647], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.1349, 56.7772], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.2197, 56.9819], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.2818, 57.1736], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.3268, 57.3562], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.3505, 57.5234], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.3510, 57.6756], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.3280, 57.8076], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.2837, 57.9252], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.2183, 58.0248], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.1304, 58.1025], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([42.0208, 58.1624], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([41.8909, 58.1998], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([41.7427, 58.2191], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([41.5806, 58.2176], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([41.4037, 58.1998], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([41.2112, 58.1617], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([41.0067, 58.1061], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([40.7899, 58.0347], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([40.5628, 57.9483], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([40.3315, 57.8488], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([40.0916, 57.7334], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([39.8527, 57.6081], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([39.6058, 57.4670], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([39.3601, 57.3185], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([39.1157, 57.1604], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([38.8734, 56.9963], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([38.6344, 56.8214], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([38.4010, 56.6446], device='cuda:0') tensor([0., 0.], device='cuda:0')

# %%
def eval(model, dataloader):
    model.eval()
    total_loss = 0
    with torch.no_grad():
        for inputs in dataloader:
            hidden = None
            loss = 0
            seq_len = inputs.size(1)
            current_input = inputs[:, 0, :].unsqueeze(1)

            for t in range(seq_len):
                prediction, hidden = model(current_input, hidden)
                current_input = inputs[:, t, :].unsqueeze(1)
                loss += criterion(prediction, inputs[:, t, :])

            total_loss += loss.item()

    print(f'Validation Loss: {total_loss / len(dataloader)}')
