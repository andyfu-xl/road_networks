# %%
import sys
import random
import torch
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader, Dataset
import sumolib
import traci
from sumolib import checkBinary
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.data import Data
import sys
import io
from contextlib import redirect_stdout
import matplotlib.pyplot as plt
import pandas as pd
import os
import math
from utils import *


if 'SUMO_HOME' in os.environ:
    print('SUMO_HOME found')
    sys.path.append(os.path.join(os.environ['SUMO_HOME'], 'tools'))

sumoBinary = checkBinary('sumo-gui')
# sumoBinary = checkBinary('sumo')
roadNetwork = "./config/osm.sumocfg"
sumoCmd = [sumoBinary, "-c", roadNetwork, "--start", "--quit-on-end"]
# use gpu if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device: " + str(device))
# Out:
# SUMO_HOME found
# SUMO_HOME found
# Using device: cuda

# %%
planned_path = get_planned_path()
path_values = list(planned_path.values())
# Out:
#  Retrying in 1 seconds
# ***Starting server on port 36873 ***
# Loading net-file from './config/osm.net.xml.gz' ... done (83ms).
# Loading additional-files from './config/osm.poly.xml.gz' ... done (223ms).
# Loading done.
# Simulation version 1.20.0 started with time: 0.00.
# Simulation ended at time: 10476.00
# Reason: TraCI requested termination.
# Performance:
#  Duration: 4.98s
#  TraCI-Duration: 3.23s
#  Real time factor: 2103.61
#  UPS: 64752.610442
# Vehicles:
#  Inserted: 1530
#  Running: 0
#  Waiting: 0
# Statistics (avg of 1530):
#  RouteLength: 1611.54
#  Speed: 7.66
#  Duration: 210.76
#  WaitingTime: 12.69
#  TimeLoss: 40.04
#  DepartDelay: 0.55

# %%
# Example DataFrame loading
df = pd.read_csv('edinburgh_trajectories.csv')
num_cols = df.shape[1]
position_indices = [i for i in range(num_cols) if i % 4 == 1 or i % 4 == 2]
position_df = df.iloc[:, position_indices]
position_array = position_df.to_numpy()
sequence_length = len(position_indices) // 2
tensor_list = []

for row in position_array:
    reshaped_tensor = torch.tensor(row.reshape(sequence_length, 2))
    tensor_list.append(reshaped_tensor)

all_trajectories_tensor = torch.stack(tensor_list) / 10

def missing(x, y, z, p):
    return torch.tensor(np.repeat(np.random.rand(x * y) < p, z).reshape(x, y, z)).float()

def generate_masks(tensors, min_mask_ratio=0.2, max_mask_ratio=0.4, missing_ratio=0.5, complete_traj_ratio=0.8):
    initial_masks = missing(tensors.shape[0], tensors.shape[1], tensors.shape[2], missing_ratio)
    masks = []
    for initial_mask in initial_masks:
        if np.random.rand() < complete_traj_ratio:
            masks.append(torch.zeros_like(initial_mask).tolist())
            continue
        seq_length = initial_mask.shape[0]
        mask_start = np.random.randint(int(seq_length * min_mask_ratio), int(seq_length * max_mask_ratio))
        mask = torch.zeros_like(initial_mask)
        mask[:, :mask_start] = 1
        mask = initial_mask * mask
        mask[0] = 0
        mask[1] = 0
        masks.append(mask.tolist())
    return torch.tensor(masks)

# split the data into training and validation sets
# because the data is randomly generated, we don't need to shuffle it
train_ratio = 0.8
train_size = int(train_ratio * all_trajectories_tensor.shape[0])
train_trajectories_tensor = all_trajectories_tensor[:train_size]
val_trajectories_tensor = all_trajectories_tensor[train_size:]

train_path_values = torch.tensor(path_values[:train_size]) / 10
val_path_values = torch.tensor(path_values[train_size:]) / 10

train_mask = generate_masks(train_trajectories_tensor)

class DatasetWithPlans(Dataset):
    def __init__(self, tensor, input_mask, path_values):
        self.tensor = tensor.float().to(device)
        self.input_mask = input_mask.float().to(device)
        self.path_values = path_values.float().to(device)
    def __len__(self):
        return len(self.tensor)
    def __getitem__(self, idx):
        return self.tensor[idx], self.input_mask[idx], self.path_values[idx]

train_dataset = DatasetWithPlans(train_trajectories_tensor, train_mask, train_path_values)

# %%
class GRUModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(GRUModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
        self.fc1 = nn.Linear(hidden_size, int(hidden_size/2))
        self.fc2 = nn.Linear(int(hidden_size/2), num_classes)
        self.relu = nn.ReLU()
    
    def forward(self, x, h0=None):
        if h0 is None:
            h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        out, hidden = self.gru(x, h0)  
        out = self.fc1(out[:, -1, :])
        out = self.relu(out)
        out = self.fc2(out)
        out = self.relu(out)
        return out, hidden

class CustomMSE(nn.Module):
    def __init__(self):
        super(CustomMSE, self).__init__()

    def forward(self, output, target):
        # where target is 0
        mask = (target != 0).float().to(device)
        mse = torch.mean(((output - target) ** 2) * mask)
        directional_diff = torch.mean(torch.abs(torch.atan2(output[:, 1], output[:, 0]) - torch.atan2(target[:, 1], target[:, 0])))
        return mse + directional_diff

# %%
def project_to_nearest(prediction, planned_path):
    with torch.no_grad():
        starts = planned_path[:, :-1, :]
        to = planned_path[:, 1:, :]

        prediction = prediction.unsqueeze(1).repeat(1, starts.shape[1], 1)
        ap = prediction - starts
        ab = to - starts
        numerator = torch.einsum('ijk,ijk->ij', ap, ab)
        denominator = torch.einsum('ijk,ijk->ij', ab, ab)
        t = numerator / denominator
        t = torch.nan_to_num(t, nan=0.0)
        t = torch.clamp(t, 0, 1)
        projections = starts + t.unsqueeze(2) * ab
        diff = projections - prediction
        distances = torch.norm(diff, dim=2)
        min_indices = torch.argmin(distances, dim=1)
        projections = projections[range(projections.shape[0]), min_indices]
        return projections

# %%
def train_model(model, dataloader, epochs, optimizer, criterion):
    model.train()
    for epoch in range(epochs):
        total_loss = 0
        for inputs, masks, planned_path in dataloader:
            optimizer.zero_grad()
            hidden = None
            loss = 0
            # Autoregressive prediction
            # Start with the first input and predict each subsequent step
            seq_len = inputs.size(1)
            current_input = inputs[:, 0, :].unsqueeze(1)
            for t in range(1, seq_len):
                prediction, hidden = model(current_input, hidden)

                previous_input = inputs[:, t-1, :]
                if epoch > 30:
                    if epoch > 40:
                        # print(t, epoch)
                        # print("predicted")
                        # print(prediction[0])
                        projected = project_to_nearest(prediction, planned_path)
                        # print("projected")
                        # print(projected[0])
                        # print("actual")
                        # print(inputs[:, t, :][0])
                        if prediction.isnan().any():
                            break
                        current_input = (projected * masks[:, t, :] + inputs[:, t, :] * (1-masks[:, t, :])).unsqueeze(1)
                    else:
                        current_input = (prediction * masks[:, t, :] + inputs[:, t, :] * (1-masks[:, t, :])).unsqueeze(1)
                else:
                    current_input = inputs[:, t, :].unsqueeze(1)
                loss += criterion(prediction - previous_input, inputs[:, t, :]-previous_input) #(current_input-previous_input).squeeze(1))
                
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
 
        print(f'Epoch {epoch+1}, Loss: {total_loss / len(dataloader)}')

train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)

model = GRUModel(input_size=2, hidden_size=128, num_layers=2, num_classes=2).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = CustomMSE()
train_model(model, train_dataloader, 50, optimizer, criterion)
# Out:
# Epoch 1, Loss: 1427475.840625
# Epoch 2, Loss: 1383796.70625
# Epoch 3, Loss: 1315500.825
# Epoch 4, Loss: 1267752.6125
# Epoch 5, Loss: 1012911.75
# Epoch 6, Loss: 706625.1328125
# Epoch 7, Loss: 503822.771875
# Epoch 8, Loss: 361986.04375
# Epoch 9, Loss: 243861.7859375
# Epoch 10, Loss: 165344.46796875
# Epoch 11, Loss: 119757.9625
# Epoch 12, Loss: 92628.2537109375
# Epoch 13, Loss: 77675.51796875
# Epoch 14, Loss: 61885.7173828125
# Epoch 15, Loss: 43761.770703125
# Epoch 16, Loss: 26485.97265625
# Epoch 17, Loss: 15335.294970703126
# Epoch 18, Loss: 11014.0578125
# Epoch 19, Loss: 9820.010693359374
# Epoch 20, Loss: 9267.239965820312
# Epoch 21, Loss: 8947.022314453125
# Epoch 22, Loss: 9106.171923828126
# Epoch 23, Loss: 8782.89033203125
# Epoch 24, Loss: 8756.668627929688
# Epoch 25, Loss: 8686.086547851562
# Epoch 26, Loss: 8458.779418945312
# Epoch 27, Loss: 8556.994604492187
# Epoch 28, Loss: 8537.5310546875
# Epoch 29, Loss: 8392.732641601562
# Epoch 30, Loss: 8543.315698242188
# Epoch 31, Loss: 8410.270703125
# Epoch 32, Loss: 11921.220068359375
# Epoch 33, Loss: 9414.005712890625
# Epoch 34, Loss: 9120.7107421875
# Epoch 35, Loss: 8720.172436523437
# Epoch 36, Loss: 8646.676245117187
# Epoch 37, Loss: 8557.513208007813
# Epoch 38, Loss: 8612.792724609375
# Epoch 39, Loss: 8566.667797851562
# Epoch 40, Loss: 8495.744580078124
# Epoch 41, Loss: 8433.481909179687
# Epoch 42, Loss: 8540.148608398438
# Epoch 43, Loss: 8333.878881835937
# Epoch 44, Loss: 8385.396362304688
# Epoch 45, Loss: 8303.14609375
# Epoch 46, Loss: 8340.075512695312
# Epoch 47, Loss: 8249.670385742187
# Epoch 48, Loss: 8298.518139648437
# Epoch 49, Loss: 8238.8064453125
# Epoch 50, Loss: 8384.936474609374

# %%
def checkModel(model, inputs, masks, paths):
    model.eval()
    with torch.no_grad():
        hidden = None
        seq_len = inputs.size(1)
        current_input = inputs[:, 0, :].unsqueeze(1)
        for t in range(1, seq_len):
            prediction, hidden = model(current_input, hidden)
            projected = project_to_nearest(prediction, paths)
            current_input = (projected * masks[:, t, :] + inputs[:, t, :] * (1-masks[:, t, :])).unsqueeze(1)
            print(projected[2], inputs[:, t, :][2])

# get the first batch in dataloader
val_mask = generate_masks(val_trajectories_tensor, missing_ratio=0.9, complete_traj_ratio=0)
val_dataset = DatasetWithPlans(val_trajectories_tensor, val_mask, val_path_values)
val_dataloader = DataLoader(val_dataset, batch_size=64, shuffle=True)
inputs, masks, paths = next(iter(val_dataloader))

checkModel(model, inputs, masks, paths)
# Out:
# tensor([90.1600, 24.6880], device='cuda:0') tensor([90.8511, 25.0030], device='cuda:0')
# tensor([90.7720, 24.9670], device='cuda:0') tensor([91.1982, 25.1613], device='cuda:0')
# tensor([91.4188, 25.2618], device='cuda:0') tensor([91.7239, 25.4009], device='cuda:0')
# tensor([92.3640, 25.6927], device='cuda:0') tensor([92.3756, 25.6980], device='cuda:0')
# tensor([93.5530, 26.2219], device='cuda:0') tensor([93.1041, 26.0232], device='cuda:0')
# tensor([95.2779, 26.4987], device='cuda:0') tensor([93.7963, 26.3286], device='cuda:0')
# tensor([137.8182,   5.9641], device='cuda:0') tensor([137.7527,   6.0440], device='cuda:0')
# tensor([138.2035,   5.4941], device='cuda:0') tensor([138.2827,   5.3974], device='cuda:0')
# tensor([138.5750,   5.0408], device='cuda:0') tensor([138.7904,   4.7780], device='cuda:0')
# tensor([138.9310,   4.6064], device='cuda:0') tensor([139.2745,   4.1874], device='cuda:0')
# tensor([139.2744,   4.1874], device='cuda:0') tensor([139.7798,   3.5708], device='cuda:0')
# tensor([139.5988,   3.7917], device='cuda:0') tensor([140.2588,   2.9864], device='cuda:0')
# tensor([139.9058,   3.4171], device='cuda:0') tensor([140.7514,   2.3855], device='cuda:0')
# tensor([140.1969,   3.0619], device='cuda:0') tensor([141.2404,   1.7888], device='cuda:0')
# tensor([140.4726,   2.7255], device='cuda:0') tensor([141.7495,   1.1677], device='cuda:0')
# tensor([140.7318,   2.4093], device='cuda:0') tensor([142.0440,   0.8088], device='cuda:0')
# tensor([140.9785,   2.1083], device='cuda:0') tensor([142.2277,   0.6416], device='cuda:0')
# tensor([143.3958,   1.7570], device='cuda:0') tensor([142.5083,   0.8471], device='cuda:0')
# tensor([144.4141,   2.8000], device='cuda:0') tensor([142.9003,   1.2494], device='cuda:0')
# tensor([145.4666,   3.8779], device='cuda:0') tensor([143.4073,   1.7688], device='cuda:0')
# tensor([147.6825,   4.0756], device='cuda:0') tensor([143.9583,   2.3332], device='cuda:0')
# tensor([145.5029,   3.9152], device='cuda:0') tensor([144.4784,   2.8659], device='cuda:0')
# tensor([145.9251,   4.3476], device='cuda:0') tensor([145.0330,   3.4339], device='cuda:0')
# tensor([147.5500,   4.2037], device='cuda:0') tensor([145.5466,   3.9599], device='cuda:0')
# tensor([148.2858,   3.4765], device='cuda:0') tensor([146.0302,   4.4549], device='cuda:0')
# tensor([148.8619,   2.9515], device='cuda:0') tensor([146.6886,   4.7617], device='cuda:0')
# tensor([149.2755,   2.5876], device='cuda:0') tensor([147.2813,   4.4622], device='cuda:0')
# tensor([149.7233,   2.2061], device='cuda:0') tensor([147.8182,   3.9410], device='cuda:0')
# tensor([150.2859,   1.7553], device='cuda:0') tensor([148.3910,   3.3733], device='cuda:0')
# tensor([150.8650,   1.3117], device='cuda:0') tensor([148.9828,   2.8432], device='cuda:0')
# tensor([151.4794,   0.8565], device='cuda:0') tensor([149.6039,   2.3078], device='cuda:0')
# tensor([152.1887,   0.3826], device='cuda:0') tensor([150.2349,   1.7952], device='cuda:0')
# tensor([152.4640,   0.2110], device='cuda:0') tensor([150.8909,   1.2920], device='cuda:0')
# tensor([152.4640,   0.2110], device='cuda:0') tensor([151.5300,   0.8210], device='cuda:0')
# tensor([152.4640,   0.2110], device='cuda:0') tensor([152.1348,   0.4162], device='cuda:0')
# tensor([152.4640,   0.2110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([152.4640,   0.2110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([152.4640,   0.2110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([152.4640,   0.2110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([152.4640,   0.2110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([152.4640,   0.2110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([152.4640,   0.2110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([152.4640,   0.2110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([152.4640,   0.2110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([152.4640,   0.2110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([152.4640,   0.2110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([152.4640,   0.2110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([152.4640,   0.2110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([152.4640,   0.2110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([152.4640,   0.2110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([152.4640,   0.2110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([152.4640,   0.2110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([152.4640,   0.2110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([152.4640,   0.2110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([152.4640,   0.2110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([152.4640,   0.2110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([152.4640,   0.2110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([22.0731,  0.0305], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([20.7700,  0.0287], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.7406, 0.0107], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.2538, 0.0114], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.0297, 0.0111], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.8203, 0.0108], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.1579, 0.0113], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.9580, 0.0124], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([9.8226, 0.0136], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([10.8609,  0.0150], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([11.9203,  0.0165], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([12.8906,  0.0178], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([13.8343,  0.0191], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([14.8169,  0.0205], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([15.8251,  0.0219], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([16.7497,  0.0232], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([5.7446, 0.0080], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([5.6402, 0.0078], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([5.8056, 0.0080], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([6.3718, 0.0088], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.1756, 0.0099], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.4672, 0.0103], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.1329, 0.0099], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.1112, 0.0098], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([6.
], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.9660, 0.0124], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([9.0716, 0.0126], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([9.1890, 0.0127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([9.3307, 0.0129], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([9.5424, 0.0132], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([9.8013, 0.0136], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([10.1255,  0.0140], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([10.5658,  0.0146], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([11.0905,  0.0153], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([11.6770,  0.0162], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([12.2991,  0.0170], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([12.9352,  0.0179], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([13.5744,  0.0188], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([14.2142,  0.0197], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([14.8389,  0.0205], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([5.4258, 0.0075], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([6.9815, 0.0097], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.4084, 0.0103], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.4552, 0.0103], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.6928, 0.0106], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.2814, 0.0115], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.7753, 0.0121], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([9.0706, 0.0126], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([9.2041, 0.0127], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([9.3167, 0.0129], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([6.6305, 0.0092], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.4203, 0.0103], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.7236, 0.0107], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.7268, 0.0107], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.9188, 0.0110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([6.9532, 0.0096], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.5978, 0.0105], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.0917, 0.0112], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.9478, 0.0110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.7414, 0.0107], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.6491, 0.0106], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.6720, 0.0106], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.8600, 0.0109], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([6.8661, 0.0095], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.5204, 0.0104], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.1423, 0.0113], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.0214, 0.0111], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.7346, 0.0107], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.5592, 0.0105], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.5299, 0.0104], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.6878, 0.0106], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.9832, 0.0110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.2981, 0.0115], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.5205, 0.0118], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.6157, 0.0119], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.6318, 0.0119], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([6.9271, 0.0096], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.4697, 0.0103], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.8268, 0.0108], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.7011, 0.0107], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.5529, 0.0105], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.5387, 0.0104], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.6220, 0.0105], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.8233, 0.0108], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.1053, 0.0112], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.3831, 0.0116], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([6.9617, 0.0096], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.5482, 0.0104], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.0240, 0.0111], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.9029, 0.0109], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.6708, 0.0106], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.5585, 0.0105], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.5663, 0.0105], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([6.6202, 0.0092], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.0992, 0.0098], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.9772, 0.0110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.0501, 0.0111], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.7509, 0.0107], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.5045, 0.0104], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.4560, 0.0103], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([6.4630, 0.0089], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([6.8717, 0.0095], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.7268, 0.0107], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.0968, 0.0112], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([6.2758, 0.0087], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([6.7448, 0.0093], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.6015, 0.0105], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.2566, 0.0114], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.0447, 0.0111], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.7019, 0.0107], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.5525, 0.0105], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.5743, 0.0105], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.6603, 0.0106], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.7326, 0.0107], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([6.5854, 0.0091], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.0389, 0.0097], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.9183, 0.0110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.1544, 0.0113], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([6.3050, 0.0087], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([6.6875, 0.0093], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.4433, 0.0103], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.2130, 0.0114], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.0680, 0.0112], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.7285, 0.0107], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.5582, 0.0105], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.5628, 0.0105], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([6.3065, 0.0087], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([6.6642, 0.0092], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.4115, 0.0103], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.1294, 0.0113], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.9554, 0.0110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.6331, 0.0106], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.4876, 0.0104], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.5143, 0.0104], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.6100, 0.0105], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.6921, 0.0106], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.7637, 0.0107], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.8679, 0.0109], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.9458, 0.0110], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.0146, 0.0111], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.0883, 0.0112], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.1716, 0.0113], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.2597, 0.0114], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.3474, 0.0116], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([6.8963, 0.0095], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.3856, 0.0102], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.9052, 0.0109], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.8244, 0.0108], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.6104, 0.0105], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.4644, 0.0103], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.4668, 0.0103], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.5938, 0.0105], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([7.8410, 0.0109], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.1165, 0.0112], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.3253, 0.0115], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.4317, 0.0117], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.4650, 0.0117], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.4853, 0.0117], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.5375, 0.0118], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.6340, 0.0119], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.7597, 0.0121], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([8.8904, 0.0123], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([6.8533, 0.0095], device='cuda:0') tensor([0., 0.], device='cuda:0')
# tensor([5.0233, 0.0070], device='cuda:0') tensor([0., 0.], device='cuda:0')

# %%
def evaluate_model(model, dataloader):
    model.eval()
    total_loss = 0
    steps = 0
    for inputs, masks, paths in dataloader:
        hidden = None
        loss = 0
        seq_len = inputs.size(1)
        current_input = inputs[:, 0, :].unsqueeze(1)
        for t in range(1, seq_len):
            new_steps = int(sum((inputs[:, t, :].reshape(-1) != 0).float().to(device))) / 2
            if new_steps == 0:
                break
            steps += new_steps
            prediction, hidden = model(current_input, hidden)
            projected = project_to_nearest(prediction, paths)
            current_input = (projected * masks[:, t, :] + inputs[:, t, :] * (1-masks[:, t, :])).unsqueeze(1)
            loss += torch.norm((projected - inputs[:, t, :]) * 10, dim=1) * (inputs[:, t, :] != 0)[:, 0]
        total_loss += loss.sum().item()
    print(f'Validation Loss: {total_loss / steps}')

for i in [0.9, 0.8, 0.7, 0.6, 0.5]:
    val_mask = generate_masks(val_trajectories_tensor, missing_ratio=i, complete_traj_ratio=0)
    val_dataset = DatasetWithPlans(val_trajectories_tensor, val_mask, val_path_values)
    val_dataloader = DataLoader(val_dataset, batch_size=64, shuffle=True)
    evaluate_model(model, val_dataloader)
# Out:
# Validation Loss: 70.80623387146325
# Validation Loss: 35.435041838192376
# Validation Loss: 22.416716748333386
# Validation Loss: 16.59096758740131
# Validation Loss: 13.331092698765016
